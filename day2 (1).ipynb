# %%
import json

# %%
data = json.load(open('/content/states_india (1).geojson'))

# %%
data.kets()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-86ae2f62dfe8> in <cell line: 1>()
# ----> 1 data.kets()
#
# AttributeError: 'dict' object has no attribute 'kets'

# %%
data.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
data['features']
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
state_name = []
for i in range(36):
  state_name.append(data['features'][i]["properties"]['st_nm'])

# %%
state_name
# Out:
# ['Telangana',
#  'Andaman & Nicobar Island',
#  'Andhra Pradesh',
#  'Arunanchal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Daman & Diu',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Chandigarh',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal',
#  'Odisha',
#  'Dadara & Nagar Havelli',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'NCT of Delhi']

# %%
state_code = []
for i in range(36):
  state_code.append(data['features'][i]["properties"]['state_code'])

# %%
state_code
# Out:
# [0,
#  35,
#  28,
#  12,
#  18,
#  10,
#  22,
#  25,
#  30,
#  24,
#  6,
#  2,
#  1,
#  20,
#  29,
#  32,
#  31,
#  23,
#  27,
#  14,
#  4,
#  34,
#  3,
#  8,
#  11,
#  33,
#  16,
#  9,
#  5,
#  19,
#  21,
#  26,
#  17,
#  15,
#  13,
#  7]

# %%
import pandas as pd

# %%
ds = pd.DataFrame({'State':state_name,'State_code':state_code})
ds
# Out:
#                        State  State_code
# 0                  Telangana           0
# 1   Andaman & Nicobar Island          35
# 2             Andhra Pradesh          28
# 3         Arunanchal Pradesh          12
# 4                      Assam          18
# 5                      Bihar          10
# 6               Chhattisgarh          22
# 7                Daman & Diu          25
# 8                        Goa          30
# 9                    Gujarat          24
# 10                   Haryana           6
# 11          Himachal Pradesh           2
# 12           Jammu & Kashmir           1
# 13                 Jharkhand          20
# 14                 Karnataka          29
# 15                    Kerala          32
# 16               Lakshadweep          31
# 17            Madhya Pradesh          23
# 18               Maharashtra          27
# 19                   Manipur          14
# 20                Chandigarh           4
# 21                Puducherry          34
# ...

# %%
data['features'].keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-3a6668f11b53> in <cell line: 1>()
# ----> 1 data['features'].keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
data['features']
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
data['features'][0]
